// %% [markdown]
// # test
// > test
//
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter]
// - image:

// %%
public class Book {


    // public void toString() { //2. tostring for title
    
    // }
    // public void bookCount(String[] array) {
    
    //     return array.length; //count of books
    // }
    private String title;
    public Book(String title){
        this.title = title;
    }
    public static int bookCount(String[][] array){
        return array.length;
    }
    public void tostring(String[][] array) {
        for (int row = 0; row < array.length; row++) {
            for (int col = 0; col < 1; col++) {
                System.out.println(array[row][col]);
            }
    
        }
    }
    public static void main (String[] args)
    {
        int counter =0;
        //array with the books
        String[][] array = {
            {"book1", "1"} , 
            {"book2", "2"},
            {"book3", "3"}
        };
      

        // System.out.println(array[0]);
        System.out.println("number of books: ");
        // System.out.println(bookCount(array));
    System.out.println("books: ");
    System.out.println(bookCount(array));

    for (int row = 0; row < array.length; row++) {  //tostring?
        for (int col = 1; col < 2; col++) {
            System.out.println("id: " + array[row][col]);
        }

    }
    for (int row = 0; row < array.length; row++) {  //tostring?
        for (int col = 0; col < 1; col++) {
            System.out.println("title: " + array[row][col]);
        }

    }

    Book book1 = new Book("book1");
    counter++;
    Book book2 = new Book("book2");
    counter++;
    System.out.println(book1.title);
    System.out.println(book2.title);
    System.out.println(counter);



}
}

    Book.main(null);
// Out:
// number of books:
// books:
// 3
// id: 1
// id: 2
// id: 3
// title: book1
// title: book2
// title: book3
// book1
// book2
// 2

// %% [markdown]
// try 2

// %%
import java.util.ArrayList;

public class Book {
    private static ArrayList<Book> library = new ArrayList<>();



    private String title;
    private int id;
    private static int nextId = 1;

    public Book(String title) {
        this.title = title;
        this.id = nextId;
        nextId++;
    }

    public String toString() {
        return "Book #" + this.id + ": " + this.title;
    }

    public static int getBookCount() {
        return library.size();
    }

    public static void main(String[] args) {

        Book[] books = {    // Use Array iniitialization to add book
            new Book("Barron's Computer Science a"),  // Set a new Book object as array element.
            new Book("Angels and Demons"),
            new Book("Lion, Witch, and a Wardrobe")
};


for (Book book : books) {
    library.add(book);
}
    

        for (Book book : books) {  
            System.out.println(book);   // this is same as book.toString()
       }

        System.out.println("Number of books in library: " + getBookCount());
        
    }
}



public class Novel extends Book {
    public void 

}
Book.main(null);
// Out:
// Book #16: Barron's Computer Science a
// Book #17: Angels and Demons
// Book #18: Lion, Witch, and a Wardrobe
// Number of books in library: 18

// %% [markdown]
// second day

// %%
public class Book{

     public Book(int id, int length, String title){
          length = 0;
          id = 1;
      }

      public static int getBookCount(String[] books){
          return array.length;
      }

System.out.println("Libary Book Count: " + Book.getBookCount());  // Notice how this method exist and works before any books are created

Book[] books = {    // Use Array iniitialization to add book
            new Book("Barron's Computer Science \"A\""),  // Set a new Book object as array element.
            new Book("Angels and Demons"),
            new Book("Lion, Witch, and a Wardrobe")
};

for (Book book : books) {  // Use Foreach syntax to iterate over array
     System.out.println(book);   // this is same as book.toString()
}

System.out.println("Libary Book Count: " + Book.getBookCount());
}
// Out:
// |   System.out.println("Libary Book Count: " + Book.getBookCount());  // Notice how this method exist and works before any books are created
// <identifier> expected
//
// |   System.out.println("Libary Book Count: " + Book.getBookCount());  // Notice how this method exist and works before any books are created
// illegal start of type
//
// |   for (Book book : books) {  // Use Foreach syntax to iterate over array
// illegal start of type
//
// |   for (Book book : books) {  // Use Foreach syntax to iterate over array
// ';' expected
//
// |   for (Book book : books) {  // Use Foreach syntax to iterate over array
// <identifier> expected
//
// |   System.out.println("Libary Book Count: " + Book.getBookCount());
// <identifier> expected
//
// |   System.out.println("Libary Book Count: " + Book.getBookCount());
// illegal start of type
