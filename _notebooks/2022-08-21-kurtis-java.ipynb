# %% [markdown]
# #Hello Java Jupyter
# > Testing the java kernel
#
# - title: Hello World Java Jupyter Kernel
# - toc: true
# - comments: true
# - categories:

# %%
System.out.println("Hello WOrld")
# Out:
# Hello WOrld
